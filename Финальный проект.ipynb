# %% [markdown]
# <h1>План работы<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импортируем-библиотеки" data-toc-modified-id="Импортируем-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем библиотеки</a></span></li><li><span><a href="#Загрузим-датасеты" data-toc-modified-id="Загрузим-датасеты-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузим датасеты</a></span></li><li><span><a href="#Посмотрим-с-чем-предстоит-нам-работать" data-toc-modified-id="Посмотрим-с-чем-предстоит-нам-работать-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Посмотрим с чем предстоит нам работать</a></span></li><li><span><a href="#После-визуального-осмотра,-проверим-все-ли-данные-у-нас-имеются" data-toc-modified-id="После-визуального-осмотра,-проверим-все-ли-данные-у-нас-имеются-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>После визуального осмотра, проверим все ли данные у нас имеются</a></span></li><li><span><a href="#Проверим-дубликаты" data-toc-modified-id="Проверим-дубликаты-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверим дубликаты</a></span></li><li><span><a href="#Общие-замечания--по-полям-датафрейма" data-toc-modified-id="Общие-замечания--по-полям-датафрейма-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Общие замечания  по полям датафрейма</a></span></li><li><span><a href="#Вывод-по-предзагруженным-данным" data-toc-modified-id="Вывод-по-предзагруженным-данным-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Вывод по предзагруженным данным</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Столбец-MultipleLines" data-toc-modified-id="Столбец-MultipleLines-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Столбец MultipleLines</a></span></li><li><span><a href="#Столбец-InternetService" data-toc-modified-id="Столбец-InternetService-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Столбец InternetService</a></span></li><li><span><a href="#Столбец-EndDate" data-toc-modified-id="Столбец-EndDate-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Столбец EndDate</a></span></li><li><span><a href="#Столбец-TotalCharges" data-toc-modified-id="Столбец-TotalCharges-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Столбец TotalCharges</a></span></li><li><span><a href="#Столбцы-EndDate-&amp;-BeginDate-&amp;-MonthlyCharges" data-toc-modified-id="Столбцы-EndDate-&amp;-BeginDate-&amp;-MonthlyCharges-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Столбцы EndDate &amp; BeginDate &amp; MonthlyCharges</a></span></li><li><span><a href="#Создадим-новый-датасет-и-объединим-наши-таблицы" data-toc-modified-id="Создадим-новый-датасет-и-объединим-наши-таблицы-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Создадим новый датасет и объединим наши таблицы</a></span></li><li><span><a href="#Посмотрим-на-имеющиеся-пропуски-и-обработаем" data-toc-modified-id="Посмотрим-на-имеющиеся-пропуски-и-обработаем-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Посмотрим на имеющиеся пропуски и обработаем</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Подготовим-признаки" data-toc-modified-id="Подготовим-признаки-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовим признаки</a></span><ul class="toc-item"><li><span><a href="#Выделим-целевой-признак-Target" data-toc-modified-id="Выделим-целевой-признак-Target-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выделим целевой признак Target</a></span></li><li><span><a href="#Добавим-новый-признак-TotalTime" data-toc-modified-id="Добавим-новый-признак-TotalTime-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавим новый признак TotalTime</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Сделаем-иссследовательский-анализ-данных---визулизация-данных,-избавление-от-выбросов" data-toc-modified-id="Сделаем-иссследовательский-анализ-данных---визулизация-данных,-избавление-от-выбросов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Сделаем иссследовательский анализ данных - визулизация данных, избавление от выбросов</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-распределение-ежемесячных-трат" data-toc-modified-id="Посмотрим-распределение-ежемесячных-трат-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрим распределение ежемесячных трат</a></span></li><li><span><a href="#Посмотрим-распределение-суммарных-трат" data-toc-modified-id="Посмотрим-распределение-суммарных-трат-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посмотрим распределение суммарных трат</a></span></li><li><span><a href="#Корреляция-между-количественными-признаками" data-toc-modified-id="Корреляция-между-количественными-признаками-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Корреляция между количественными признаками</a></span></li><li><span><a href="#Кодирование-OE" data-toc-modified-id="Кодирование-OE-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Кодирование OE</a></span></li><li><span><a href="#Дата-регистрации-клиентов-BeginDate" data-toc-modified-id="Дата-регистрации-клиентов-BeginDate-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Дата регистрации клиентов BeginDate</a></span></li><li><span><a href="#Дата-ухода-клиентов-EndDate" data-toc-modified-id="Дата-ухода-клиентов-EndDate-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Дата ухода клиентов EndDate</a></span></li><li><span><a href="#ВЫВОД" data-toc-modified-id="ВЫВОД-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>ВЫВОД</a></span></li></ul></li><li><span><a href="#Подготовим-данные-для-моделей" data-toc-modified-id="Подготовим-данные-для-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подготовим данные для моделей</a></span><ul class="toc-item"><li><span><a href="#Признаки-с-датой-удалим" data-toc-modified-id="Признаки-с-датой-удалим-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Признаки с датой удалим</a></span></li><li><span><a href="#Разделим-датафрейм-на-обучающую-и-тестовую-выборки" data-toc-modified-id="Разделим-датафрейм-на-обучающую-и-тестовую-выборки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Разделим датафрейм на обучающую и тестовую выборки</a></span></li><li><span><a href="#После-удаления-CustomerID-закодируем-с-помощью-OHE." data-toc-modified-id="После-удаления-CustomerID-закодируем-с-помощью-OHE.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>После удаления CustomerID закодируем с помощью OHE.</a></span></li><li><span><a href="#Проверим-баланс-классов" data-toc-modified-id="Проверим-баланс-классов-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проверим баланс классов</a></span></li><li><span><a href="#Применим-SMOTE-для-выравнивания-классов" data-toc-modified-id="Применим-SMOTE-для-выравнивания-классов-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Применим SMOTE для выравнивания классов</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Градиентный-бустинг-CatBoost" data-toc-modified-id="Градиентный-бустинг-CatBoost-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Градиентный бустинг CatBoost</a></span></li><li><span><a href="#Анализ-модели" data-toc-modified-id="Анализ-модели-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Анализ модели</a></span></li><li><span><a href="#Тестирование-итоговой-модели" data-toc-modified-id="Тестирование-итоговой-модели-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Тестирование итоговой модели</a></span></li><li><span><a href="#График:-значимость-факторов" data-toc-modified-id="График:-значимость-факторов-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>График: значимость факторов</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#ЗАКЛЮЧЕНИЕ" data-toc-modified-id="ЗАКЛЮЧЕНИЕ-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>ЗАКЛЮЧЕНИЕ</a></span></li><li><span><a href="#ОТЧЁТ" data-toc-modified-id="ОТЧЁТ-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>ОТЧЁТ</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Артур, привет еще раз!
#
# Я тебя понял, посмотрю твой код и возможно дам рекомендации, какие моменты может пока отложить, чтобы спокойно доделать финальный проект. А далее ты уже можешь для портфолио поработать более подробно =)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Приветствую, Артур!
#
# К сожалению в твоем проекте я обнаружил признаки списывания с источника:
#
# https://github.com/IgorMitrofanov/CustomerOutflow-study/blob/main/StudyProject_CustomerOutflow.ipynb
#
# Факт списывания также подтвердил старший ревьювер.
#
# На текущий момент мы готовы дать тебе возможность самостоятельно завершить проект, поэтому отправляю на доработку.
#
# Прошу серьезно отнестись к данному замечанию, буду ждать на проверку переделанный проект.
#
# </div>

# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Приветствую, Артур!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду проверять твою работу. Предлагаю общаться на «ты», если не против=)
#
# При проверке работ я пишу следующие комментарии:
#
# <div class="alert alert-success">
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class="alert alert-warning">
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class="alert alert-danger">
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# # Задача
#
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# # Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line, «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
#
# Также доступны такие услуги:
#
# 1. Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity);
# 2. Выделенная линия технической поддержки (TechSupport);
# 3. Облачное хранилище файлов для резервного копирования данных (OnlineBackup);
# 4. Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# # Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# 1. contract.csv — информация о договоре;
# 2. personal.csv — персональные данные клиента;
# 3. internet.csv — информация об интернет-услугах;
# 4. phone.csv — информация об услугах телефонии.
#
# Во всех файлах столбец customerID содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# # Описание полей данных
#
# 1. BeginDate – дата начала пользования услугами.
# 2. EndDate – дата окончания пользования услугами.
# 3. Type – тип оплаты: ежемесячный, годовой и тд.
# 4. PaperlessBilling – безналичный расчет.
# 5. PaymentMethod – способ оплаты.
# 6. MonthlyCharges – ежемесячные траты на услуги.
# 7. TotalCharges – всего потрачено денег на услуги.
# 8. Dependents – наличие иждивенцев.
# 9. Senior Citizen – наличие пенсионного статуса по возрасту.
# 10. Partner – наличие супруга(и).
# 11. MultipleLines – наличие возможности ведения параллельных линий во время звонка.
#
# Во всех файлах столбец customerID содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# # Цель работы
# На основе предоставленной информации сделать анализ данных и спрогнозировать дальнейшее действие клиентов. Предоставить лояльные условия клиенту, чтобы его не потерять.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, когда есть подробное описание проекта — так гораздо проще ознакомиться!
#
# Как рекомендация, можно добавить цель работы
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Кратко добавил цель моей работы. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида v2:</b> 👍
#
# </div>

# %% [markdown]
# <h1>План работы<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импортируем-библиотеки" data-toc-modified-id="Импортируем-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем библиотеки</a></span></li><li><span><a href="#Загрузим-датасеты" data-toc-modified-id="Загрузим-датасеты-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузим датасеты</a></span></li><li><span><a href="#Посмотрим-с-чем-предстоит-нам-работать" data-toc-modified-id="Посмотрим-с-чем-предстоит-нам-работать-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Посмотрим с чем предстоит нам работать</a></span></li><li><span><a href="#После-визуального-осмотра,-проверим-все-ли-данные-у-нас-имеются" data-toc-modified-id="После-визуального-осмотра,-проверим-все-ли-данные-у-нас-имеются-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>После визуального осмотра, проверим все ли данные у нас имеются</a></span></li><li><span><a href="#Проверим-дубликаты" data-toc-modified-id="Проверим-дубликаты-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверим дубликаты</a></span></li><li><span><a href="#Общие-замечания--по-полям-датафрейма" data-toc-modified-id="Общие-замечания--по-полям-датафрейма-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Общие замечания  по полям датафрейма</a></span></li><li><span><a href="#Вывод-по-предзагруженным-данным" data-toc-modified-id="Вывод-по-предзагруженным-данным-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Вывод по предзагруженным данным</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Столбец-MultipleLines" data-toc-modified-id="Столбец-MultipleLines-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Столбец MultipleLines</a></span></li><li><span><a href="#Столбец-InternetService" data-toc-modified-id="Столбец-InternetService-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Столбец InternetService</a></span></li><li><span><a href="#Столбец-EndDate" data-toc-modified-id="Столбец-EndDate-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Столбец EndDate</a></span></li><li><span><a href="#Столбец-TotalCharges" data-toc-modified-id="Столбец-TotalCharges-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Столбец TotalCharges</a></span></li><li><span><a href="#Столбцы-EndDate-&amp;-BeginDate-&amp;-MonthlyCharges" data-toc-modified-id="Столбцы-EndDate-&amp;-BeginDate-&amp;-MonthlyCharges-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Столбцы EndDate &amp; BeginDate &amp; MonthlyCharges</a></span></li><li><span><a href="#Создадим-новый-датасет-и-объединим-наши-таблицы" data-toc-modified-id="Создадим-новый-датасет-и-объединим-наши-таблицы-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Создадим новый датасет и объединим наши таблицы</a></span></li><li><span><a href="#Посмотрим-на-имеющиеся-пропуски-и-обработаем" data-toc-modified-id="Посмотрим-на-имеющиеся-пропуски-и-обработаем-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Посмотрим на имеющиеся пропуски и обработаем</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Подготовим-признаки" data-toc-modified-id="Подготовим-признаки-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовим признаки</a></span><ul class="toc-item"><li><span><a href="#Выделим-целевой-признак-Target" data-toc-modified-id="Выделим-целевой-признак-Target-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выделим целевой признак Target</a></span></li><li><span><a href="#Добавим-новый-признак-TotalTime" data-toc-modified-id="Добавим-новый-признак-TotalTime-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавим новый признак TotalTime</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Сделаем-иссследовательский-анализ-данных---визулизация-данных,-избавление-от-выбросов" data-toc-modified-id="Сделаем-иссследовательский-анализ-данных---визулизация-данных,-избавление-от-выбросов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Сделаем иссследовательский анализ данных - визулизация данных, избавление от выбросов</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-распределение-ежемесячных-трат" data-toc-modified-id="Посмотрим-распределение-ежемесячных-трат-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрим распределение ежемесячных трат</a></span></li><li><span><a href="#Посмотрим-распределение-суммарных-трат" data-toc-modified-id="Посмотрим-распределение-суммарных-трат-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посмотрим распределение суммарных трат</a></span></li><li><span><a href="#Корреляция-между-количественными-признаками" data-toc-modified-id="Корреляция-между-количественными-признаками-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Корреляция между количественными признаками</a></span></li><li><span><a href="#!!!!!!!!!!!!-Кодирование-OE-!!!!!!!!!!-Не-обязательно!" data-toc-modified-id="!!!!!!!!!!!!-Кодирование-OE-!!!!!!!!!!-Не-обязательно!-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>!!!!!!!!!!!! Кодирование OE !!!!!!!!!! Не обязательно!</a></span></li><li><span><a href="#Дата-регистрации-клиентов-BeginDate" data-toc-modified-id="Дата-регистрации-клиентов-BeginDate-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Дата регистрации клиентов BeginDate</a></span></li><li><span><a href="#Дата-ухода-клиентов-EndDate" data-toc-modified-id="Дата-ухода-клиентов-EndDate-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Дата ухода клиентов EndDate</a></span></li><li><span><a href="#ВЫВОД" data-toc-modified-id="ВЫВОД-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>ВЫВОД</a></span></li></ul></li><li><span><a href="#Подготовим-данные-для-моделей" data-toc-modified-id="Подготовим-данные-для-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подготовим данные для моделей</a></span><ul class="toc-item"><li><span><a href="#Признаки-с-датой-удалим" data-toc-modified-id="Признаки-с-датой-удалим-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Признаки с датой удалим</a></span></li><li><span><a href="#Разделим-датафрейм-на-обучающую-и-тестовую-выборки" data-toc-modified-id="Разделим-датафрейм-на-обучающую-и-тестовую-выборки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Разделим датафрейм на обучающую и тестовую выборки</a></span></li><li><span><a href="#После-удаления-CustomerID-закодируем-с-помощью-OHE." data-toc-modified-id="После-удаления-CustomerID-закодируем-с-помощью-OHE.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>После удаления CustomerID закодируем с помощью OHE.</a></span></li><li><span><a href="#Проверим-баланс-классов" data-toc-modified-id="Проверим-баланс-классов-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проверим баланс классов</a></span></li><li><span><a href="#Применим-SMOTE-для-выравнивания-классов" data-toc-modified-id="Применим-SMOTE-для-выравнивания-классов-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Применим SMOTE для выравнивания классов</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Градиентный-бустинг-CatBoost" data-toc-modified-id="Градиентный-бустинг-CatBoost-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Градиентный бустинг CatBoost</a></span></li><li><span><a href="#График:-значимость-факторов" data-toc-modified-id="График:-значимость-факторов-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>График: значимость факторов</a></span></li><li><span><a href="#Анализ-модели" data-toc-modified-id="Анализ-модели-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Анализ модели</a></span></li><li><span><a href="#Тестирование-итоговой-модели" data-toc-modified-id="Тестирование-итоговой-модели-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Тестирование итоговой модели</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> В целом по плану работ все хорошо, но необходимо еще сделать исследовательский анализ, после подготовки признаков
#
# Возможно ты так и планировал, но в плане я не увидел =)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Ислледовательский анализ данных был во втором пункте, но соглашусь с вами и перенесу его на 4 место. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида v2:</b> Хорошо
#
# </div>

# %% [markdown]
# ## Подготовка данных

# %%
# !pip install jupyter_contrib_nbextensions 
# #jupyter contrib nbextension install

# %%
# !pip install phik
# !pip install -U scikit-learn
# !pip install -U matplotlib
# !pip install -U seaborn

# %% [markdown]
# ### Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
import math

from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from catboost import CatBoostClassifier, Pool
from sklearn.utils import shuffle
from sklearn.preprocessing import OrdinalEncoder 
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import recall_score
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix, make_scorer, roc_curve

RANDOM_STATE = 270323

# %%
def init_random(state):
    random.seed(RANDOM_STATE)
    np.random.seed(RANDOM_STATE)

init_random(RANDOM_STATE)

# %% [markdown]
# ### Загрузим датасеты

# %%
contract = pd.read_csv('/datasets/final_provider/contract.csv')
internet = pd.read_csv('/datasets/final_provider/internet.csv')
personal = pd.read_csv('/datasets/final_provider/personal.csv')
phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %% [markdown]
# ### Посмотрим с чем предстоит нам работать

# %%
contract.head()
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65

# %%
contract.info()
contract.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %%
contract.info()
contract.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %%
internet.head()
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %%
internet.info()
internet.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
#         customerID InternetService OnlineSecurity OnlineBackup  \
# count         5517            5517           5517         5517
# unique        5517               2              2            2
# top     4612-THJBS     Fiber optic             No           No
# freq             1            3096           3498         3088
#
# ...

# %%
personal.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
personal.info()
personal.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
#       customerID  gender  SeniorCitizen Partner Dependents
# 1126  0927-LCSMG    Male              0      No         No
# 6359  7148-XZPHA    Male              0     Yes        Yes
# 993   9108-EQPNQ  Female              0     Yes        Yes
# 6430  2096-XOTMO  Female              0     Yes        Yes
# 1553  7776-QGYJC  Female              0     Yes        Yes

# %%
phone.head()
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %%
phone.info()
phone.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     3422-LYEPQ            No
# freq             1          3390

# %% [markdown]
# ### После визуального осмотра, проверим все ли данные у нас имеются

# %%
contract.shape, internet.shape, personal.shape, phone.shape
# Out:
# ((7043, 8), (5517, 8), (7043, 5), (6361, 2))

# %% [markdown]
# ### Проверим дубликаты

# %%
contract.duplicated().sum(), internet.duplicated().sum(), personal.duplicated().sum(), phone.duplicated().sum()
# Out:
# (0, 0, 0, 0)

# %% [markdown]
# ### Общие замечания  по полям датафрейма
# 1. customerID – содержит уникальный айди клиента;
# 2. BeginDate – поле необходимо привести к типу DATETIME;
# 3. EndDate - целевой признак, дата в этом поле соответствует оттоку клиента, значение "No" - клиент остался;
# 4. Type – тип оплаты, принимает значения: ежемесячный, годовой, двухгодовой;
# 5. PaperlessBilling – безналичный расчет, является бинарным признаком;
# 6. PaymentMethod - способ оплаты, принимает значения: электронный чек, почтовый чек, банковский перевод и кредитная карта;
# 7. MonthlyCharges - ежемесячные траты на услуги, можно привести поле к целочисленному типу для экономии памяти;
# 8. TotalCharges - всего потрачено денег на услуги, необходимо привести к числовому формату и заполнить неявные пропуски нулями.

# %% [markdown]
# ### Вывод по предзагруженным данным
# 1. Загрузили 4 таблицы с данными: contract, internet, personal, phone;
# 2. В нашей выборке 7043 договора, из них пользователи интернета - 5517, телефоном - 6361;
# 3. Как посмотрели выше, дубликаты не выявлены;
# 4. По предобработке данных необходимо:
#     - BeginDate привести к типу datetime;
#     - TotalCharges - здесь необходимо избавиться от неявных дубликатов, привести к целочислительному типу, а пустые пропуски заполнить нулями;
#     - MonthCharges - приведём к целочислительному типу данных для экономии памяти;
# 5. После предобработки данных мы объединим в одну таблицу, исследуем данные и проверим аномалии.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> Данные загружены успешно, все хорошо!
#
# Подскажи, есть ли на данном этапе какие-либо вопросы по проекту?
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> ВОПРОСЫ:
#     1. До конца толком не понял как сделать автоматическое содержание проекта, прошу подсказать.
#     2. Я правильно понимаю, что за целевой признак мы будем использовать EndDate?
#     3. Про значения метрик вы говорили на вебинаре, вроде по ним вопросов нет.
#     4. Из-за малого количества категорий, ко всем значениям применять OHE?
#
# # Большое спасибо за поддержку!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида v2:</b> По твоим вопросам:
#
# 1. на платформе содержание проекта по умолчанию автоматическое. Если делаешь проект локально нужно установить расширение nb_extensions:
#
# https://vc.ru/newtechaudit/582269-kak-povysit-produktivnost-raboty-v-jupyter-notebook-s-pomoshchyu-nbextensions
#
# 2. На основе EndDate можно получить целевой признак, лучше сделать отдельной колонкой, например Target
#
# 3. Хорошо
#
# 4. Да, допустимо применить OHE для всех моделей
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида v2:</b> План работ принят, можно приступать к основному проекту.
#
# Сохрани пожалуйста наши с тобой комментарии, а проект продолжай в этом же файле. Успехов!
# </div>

# %% [markdown]
# <h1> Комментарий ревьювера </h1>
#
# <div class="alert alert-success">
#
# 👋 Артур, привет еще раз! Это снова Арсен Абдулин — и я буду делать ревью основного проекта.
#
# Давай посмотрим, что получилось.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Столбец MultipleLines

# %%
phone.isna().sum()
# Out:
# customerID       0
# MultipleLines    0
# dtype: int64

# %%
print(phone['MultipleLines'].unique())
# Out:
# ['No' 'Yes']

# %% [markdown]
# ### Столбец InternetService

# %%
print(internet['InternetService'].unique())
# Out:
# ['DSL' 'Fiber optic']

# %% [markdown]
# ### Столбец EndDate

# %%
# contract['EndDate'].info

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Общая рекомендация по проекту:
#
# - комментарии к текущим действиям необходимо писать в ячейках Markdown, т.к. наш проект по сути является отчетом =)
#
# В комментариях с ячейками кода обычно пишут особенности выполнения кода.
#
# Нужно поправить в ячейках ниже и в других подобных ячейках, где есть комментарии к коду. Технические комментарии допустимо оставить в ячейке кода
# </div>

# %% [markdown]
# В столбце много значений No, заменим их на дату актуальности датасета 2020-02-01

# %%
contract['EndDate'] = contract['EndDate'].replace(['No'], ['2020-02-01'])

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Согласен с такой заменой
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо 👍
#
# </div>

# %% [markdown]
# Приведём к типу datetime

# %%
contract['EndDate'] = pd.to_datetime(contract['EndDate'], format='%Y-%m-%d')

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Ошибка при выполнении кода на платформе:
#
#     contract['EndDate'].info()
#
# Проверь пожалуйста, возможно в данной версии pandas это команда не сработает для pd.Series
#
# </div>

# %%
# contract['EndDate'].info()

# %% [markdown]
# ### Столбец TotalCharges

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Здесь такая же ошибка
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Выполняю в Jupyter Lab, всё работает без всяких проблем!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v2:</b> Есть также требования, чтобы проект выполнялся на платформе
#
# Мне еще не совсем понятно, для чего нужно выводить info только по объекту Series ?
#
# </div>

# %%
# contract['TotalCharges'].info()

# %%
contract['TotalCharges'] = pd.to_numeric(contract['TotalCharges'], errors='coerce')

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   datetime64[ns]
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7032 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# ### Столбцы EndDate & BeginDate & MonthlyCharges

# %% [markdown]
# Поля EndDate и BeginDate приведём к типу datetime. MonthlyCharges и TotalCharges сделаем целочислительным.

# %%
contract['BeginDate'] = pd.to_datetime(contract['BeginDate'],format = '%Y-%m-%d')
contract['EndDate'] = pd.to_datetime(contract['EndDate'],format = '%Y-%m-%d')

contract['MonthlyCharges'] = contract['MonthlyCharges'].astype('int')
contract['TotalCharges'] = contract['TotalCharges'].astype('float')

# %%
contract['TotalCharges'].sample()
# Out:
# 5454    69.55
# Name: TotalCharges, dtype: float64

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   datetime64[ns]
#  2   EndDate           7043 non-null   datetime64[ns]
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   int64
#  7   TotalCharges      7032 non-null   float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 440.3+ KB

# %%
contract.shape
# Out:
# (7043, 8)

# %% [markdown]
# ### Создадим новый датасет и объединим наши таблицы

# %% [markdown]
# Произведём финишную предобработку и объединим наши таблицы в одну

# %%
df = contract.merge(internet, on='customerID', how='left')
df = df.merge(personal, on='customerID', how='left')
df = df.merge(phone, on='customerID', how='left')

# %%
df.sample(5)
# Out:
#       customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 2427  7854-FOKSF 2019-12-01 2020-01-01  Month-to-month               No
# 2188  3689-MOZGR 2017-09-01 2020-02-01  Month-to-month              Yes
# 1282  6260-ONULR 2020-01-01 2020-02-01  Month-to-month              Yes
# 720   4697-LUPSU 2019-12-01 2020-02-01        One year               No
# 871   1573-LGXBA 2015-05-01 2020-02-01        One year              Yes
#
#                 PaymentMethod  MonthlyCharges  TotalCharges InternetService  \
# 2427         Electronic check              35         35.90             DSL
# 2188         Electronic check              31        926.20             DSL
# 1282             Mailed check              62         62.80             DSL
# 720              Mailed check              20         34.75             NaN
# 871   Credit card (automatic)              97       5598.00     Fiber optic
#
# ...

# %%
df['customerID'].nunique()
# Out:
# 7043

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   datetime64[ns]
#  2   EndDate           7043 non-null   datetime64[ns]
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   int64
#  7   TotalCharges      7032 non-null   float64
#  8   InternetService   5517 non-null   object
#  9   OnlineSecurity    5517 non-null   object
#  10  OnlineBackup      5517 non-null   object
#  11  DeviceProtection  5517 non-null   object
#  12  TechSupport       5517 non-null   object
#  13  StreamingTV       5517 non-null   object
#  14  StreamingMovies   5517 non-null   object
#  15  gender            7043 non-null   object
# ...

# %% [markdown]
# ### Посмотрим на имеющиеся пропуски и обработаем

# %%
df.isna().sum()
# Out:
# customerID             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges          11
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# MultipleLines        682
# dtype: int64

# %% [markdown]
# В общих расходах пользователя - TotalCharges имеются 11 пропусков. У этих пользователей начальная дата 01.02.2022. Похоже что это новые пользователи и для них ещё не загружены общие расходы. Предлагаю заменить пропуски на значения столбца MonthlyCharges.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Объединение датасетов выполнено успешно!
#
# Хорошо, что обратил на пустые строки в признаке TotalCharges! Согласен, можно заменить такие пропуски на ежемесячные платежи
#
# </div>

# %%
df.loc[df['TotalCharges'].isna(), 'TotalCharges'] = df['MonthlyCharges']

# %%
df.isna().sum()
# Out:
# customerID             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# MultipleLines        682
# dtype: int64

# %% [markdown]
# Пропуски в услугах можно заменить на значение 'no'.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо, можно заполнить пропуски таким образом
#
# </div>

# %%
df[['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 
    'StreamingMovies']] = df[['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                                    'TechSupport', 'StreamingTV', 'StreamingMovies']].fillna('No')

# %% [markdown]
# В столбце MultipleLines две категории. Пропуски можно заполнить no_telefon - отсутствие телефона.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Все правильно, MultipleLines категориальный признак!
#
# </div>

# %%
df['MultipleLines'] = df['MultipleLines'].fillna('no_telefon')

# %%
print(df['InternetService'].unique())
print(df['MultipleLines'].unique())
# Out:
# ['DSL' 'Fiber optic' 'No']
# ['no_telefon' 'No' 'Yes']

# %%
df.isna().sum()
# Out:
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# MultipleLines       0
# dtype: int64

# %% [markdown]
# ### Вывод:
#     1. Столбец EndDate и BeginDate привели к типу datetime;
#     2. Столбец TotalCharge - float;
#     3. В столбце EndDate значения No заменили на дату актуальности датасета;
#     4. После объединения таблиц у нас получился новый датасет;
#     5. В столбце MultipleLines две категории и 682 пропущенных значения. Пропуски заполнили no_telefon - отсутствие телефона;
#     6. В общих расходах пользователя - TotalCharges было 11 пропусков. У этих пользователей начальная дата 01.02.2022.Заменили пропуски на значения столбца        MonthlyCharges;
#     7. После предобработки избавились от всех пропусков. В датасете отсутствуют клиенты, которые вообще ничем не пользуются.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Предобработка данных выполнена успешно!
#
# </div>

# %% [markdown]
# ## Подготовим признаки

# %% [markdown]
# ### Выделим целевой признак Target

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Отлично, получили целевую переменную!
#
# </div>

# %% [markdown]
# Выделим целевой признак Target, который будет показывать отказался клиент от услуг или нет. Значения поменяем с No на 0 и Yes на 1.

# %%
df['Target'] = (df['EndDate'] != '2020-02-01').astype(int)
df.head()
# Out:
#    customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month              Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year               No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month              Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year               No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges InternetService  \
# 0           Electronic check              29         29.85             DSL
# 1               Mailed check              56       1889.50             DSL
# 2               Mailed check              53        108.15             DSL
# 3  Bank transfer (automatic)              42       1840.75             DSL
# 4           Electronic check              70        151.65     Fiber optic
#
#   OnlineSecurity  ... DeviceProtection TechSupport StreamingTV  \
# ...

# %% [markdown]
# ### Добавим новый признак TotalTime

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо, получили новый полезный признак для обучения
#
# </div>

# %% [markdown]
# Добавим в нашу табличку ещё один столбец - TotalTime. В него мы занесём количество дней которыми пользовался клиент услугами.

# %%
df['TotalTime'] = (df['EndDate'] - df['BeginDate']).dt.days

# %%
df.head()
# Out:
#    customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month              Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year               No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month              Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year               No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges InternetService  \
# 0           Electronic check              29         29.85             DSL
# 1               Mailed check              56       1889.50             DSL
# 2               Mailed check              53        108.15             DSL
# 3  Bank transfer (automatic)              42       1840.75             DSL
# 4           Electronic check              70        151.65     Fiber optic
#
#   OnlineSecurity  ... TechSupport StreamingTV StreamingMovies  gender  \
# ...

# %%
df.nunique()
# Out:
# customerID          7043
# BeginDate             77
# EndDate                5
# Type                   3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges        99
# TotalCharges        6531
# InternetService        3
# OnlineSecurity         2
# OnlineBackup           2
# DeviceProtection       2
# TechSupport            2
# StreamingTV            2
# StreamingMovies        2
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# MultipleLines          3
# Target                 2
# TotalTime            156
# dtype: int64

# %% [markdown]
# ### Вывод:
#     1. Выделили целевой признак Target - показывает отказался клиень от услуг или нет;
#     2. Добавили столбец TotalTime, который показывает количество дней от заключения контракта до выгрузки данных 'TotalTime'.

# %% [markdown]
# ## Сделаем иссследовательский анализ данных - визулизация данных, избавление от выбросов

# %% [markdown]
# ### Посмотрим распределение ежемесячных трат

# %%
sns.histplot(df['MonthlyCharges']);
plt.title('Распределение значений месячных трат (MonthlyCharges)')
plt.xlabel('Месячные траты');

# %% [markdown]
# Пик распределения величины ежемесячного платежа для ушедших клиетов выше, чем для оставшихся. Ушедшие клиенты платили больше.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Вывод скорее всего правильный, но на графике этого не видно
#
# Для визуализации распределения для ушедших и оставшихся клиентов можно использовать метод histplot:
#
# https://seaborn.pydata.org/generated/seaborn.histplot.html
#
#     sns.histplot(data=data, x=column, hue ='Target', multiple='stack')
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо 👍
#
# </div>

# %% [markdown]
# ### Посмотрим распределение суммарных трат

# %%
plt.figure(figsize=(10,5))
df['TotalCharges'].hist(bins=100, density=True, label='Траты в месяц', alpha=1, color='k');
plt.title('Распределение значений суммарных трат (TotalCharges)')
plt.xlabel('Суммарные траты');

# %% [markdown]
# Есть выбросы в общих платежах для ушедших клиентов. Они попадают в нормальные значения для оставшихся клиентов.

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий тимлида:</b> В проекте нужно обязательно сделать исследовательский анализ данных, построить графики для ушедших и оставшихся клиентов.
#
# Можно также рассмотреть категориальные признаки
#
# Сейчас на графиках пока что общие распределения, без разделения по группам клиентов
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Замечание поправлено 👍
#
# </div>

# %% [markdown]
# Посмотрим как распредлены месячные траты ушедших и всех клиентов:

# %%
ax = sns.histplot(df.loc[df['Target'] == 1,'MonthlyCharges'], 
                  color='k', 
                  label='Ушедшие клиенты')
sns.histplot(df['MonthlyCharges'],
             ax=ax, 
             alpha=0.25, 
             label='Все клиенты')
ax.legend()
plt.title('Распределение значений ежемесячных трат (MonthlyCharges)')
plt.xlabel('Ежемесячные траты');

# %% [markdown]
# Как мы можем наблюдать, ушедшие клиенты в основном пользовались более дорогими тарифами.

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Все хорошо, вывод правильный!
#
# Действительно, в отток попали более платежеспособные клиенты
#
# </div>

# %% [markdown]
# ### Корреляция между количественными признаками

# %% [markdown]
# Посмотрим корреляцию между всеми количественными данными

# %%
numeric_columns = ['MonthlyCharges', 'TotalCharges', 'TotalTime']
df[numeric_columns].corr()
# Out:
#                 MonthlyCharges  TotalCharges  TotalTime
# MonthlyCharges        1.000000      0.651245   0.247771
# TotalCharges          0.651245      1.000000   0.826095
# TotalTime             0.247771      0.826095   1.000000

# %% [markdown]
# Можно заметить, что у нас присутствует проблема мультиколлинеарности в данных - корреляция между TotalCharges и TotalDays - 0.82, что логично - чем дольше клиент платит, тем больше итоговая сумма. Удалим поле TotalCharges

# %%
del df['TotalCharges']
numeric_columns = ['MonthlyCharges', 'TotalTime']

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Правильно, что проверил корреляцию Пирсона только для числовых признаков!
#
# Вывод правильный, действительно есть мультиколлинеарность
#
# </div>

# %% [markdown]
# ### Кодирование OE

# %% [markdown]
# Для того, чтобы преобразовать категоральные признаки в численные мы применим технику OHE (One-Hot Encoding)

# %%
# df_ohe = pd.get_dummies(df, columns = ['Type', 'InternetService','PaymentMethod'], drop_first=True)

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> К сожалению есть ошибка в кодировании признаков.
#
# Чтобы не было утечки, необходимо сначала разделить данные на выборки, а затем выполнять кодирование
#
# Если используешь get_dummies, нужно обязательно сравнить список признаков после кодирования:
#
#     features_train.columns == features_test.columns
#
# Нужно указать также признаки для кодирования, у тебя сейчас закодировался индекс клиента
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Решил прислушаться вашего совета и применить кодирование после разбиения датасета. Для примера применения техники OE оставил в комментах.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Понял, хорошо
#
# </div>

# %% [markdown]
# Закодируем уcлуги с помощью OrdinalEncoder.

# %%
# services = ['Type', 'PaperlessBilling','PaymentMethod', 'InternetService','OnlineSecurity',
#                 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 
#                 'StreamingMovies', 'gender', 'Partner', 'Dependents', 'MultipleLines']

# %%
# encoder = OrdinalEncoder()
# encoder.fit(df[services])
# df[services] = pd.DataFrame(encoder.transform(df[services]), columns=df[services].columns)
# df.head()

# %%
df.head()
# Out:
#    customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month              Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year               No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month              Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year               No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges InternetService OnlineSecurity  \
# 0           Electronic check              29             DSL             No
# 1               Mailed check              56             DSL            Yes
# 2               Mailed check              53             DSL            Yes
# 3  Bank transfer (automatic)              42             DSL            Yes
# 4           Electronic check              70     Fiber optic             No
#
#   OnlineBackup  ... TechSupport StreamingTV StreamingMovies  gender  \
# ...

# %%
# df.head()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Дублирование кода, нужно удалить лишнюю таблицу
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил!
# </div>

# %% [markdown]
# ### Дата регистрации клиентов BeginDate

# %%
df['BeginDate'].hist(bins=100, density=True, label='Траты в месяц', alpha=1, color='k');
plt.title('Факт регистрации клиентов во времени (BeginDate)')
plt.xlabel('Год');

# %% [markdown]
# В начале 2014 года был большой прирост клиентов. Это связано с началом старта бизнеса. С начала 2015 по конец 2018 года - величина клиентов умеренно растёт. С начала 2019 года наблюдается бурный рост количества новых клиентов.

# %% [markdown]
# ### Дата ухода клиентов EndDate

# %%
df['EndDate'].hist(bins=10, density=True, alpha=1, color='k');
plt.title('Отток клиентов во времени (EndDate)')
plt.xlabel('Год');

# %% [markdown]
# Самые большие скочки оттока клиентов приходятся на 2019 и 2020 года.

# %%
plt.figure(figsize=(10,5))
df['TotalTime'].hist(bins=100, density=True, label='Траты в месяц', alpha=1, color='k');
plt.title('Общее время клиента в компании')
plt.xlabel('TotalTime - дней');

# %%
df.query('Target == 1')['TotalTime'].describe()
# Out:
# count    1869.000000
# mean      547.352060
# std       594.389607
# min        30.000000
# 25%        61.000000
# 50%       304.000000
# 75%       883.000000
# max      2191.000000
# Name: TotalTime, dtype: float64

# %%
df['TotalTime'].describe()
# Out:
# count    7043.000000
# mean      985.996166
# std       747.587844
# min         0.000000
# 25%       273.000000
# 50%       883.000000
# 75%      1676.000000
# max      2191.000000
# Name: TotalTime, dtype: float64

# %% [markdown]
# Средняя длительность пользования услугами ушедших клиентов в два раза меньше, чем у тех, которые остались.

# %% [markdown]
# ### ВЫВОД
#
# 1) Все задачи для предобработки данных сделали:
#
#     1. BeginDate – поле приведено к типу datetime;
#
#     2. EndDate – для значений "No" установлена "заглушка", соответствующая дате актуальности датасета - 2020-02-01), после чего поле было приведено к формату datetime;
#
#     3. MonthlyCharges - поле приведено к целочисленному типу для экономии памяти (два знака после запятой - излишняя точность в значениях);
#
#     4. TotalCharges - неявные пропуски (пустые значения) приведены в соответствие с полем суммарных трат, так как пропуски маркеруют клиентов, начавших пользоваться услагми компании в феврале 2020 года.
#
# 2) Все датафреймы объединили.
#
# 3) Распределение ежемесячных трат: Пик распределения величины ежемесячного платежа для ушедших клиетов выше, чем для оставшихся. Ушедшие клиенты платили больше.
#
# 4) Есть выбросы в общих платежах для ушедших клиентов. Они попадают в номарльные значения для оставшихся клиентов.
#
# 5) Можно заметить, что у нас присутствует проблема мультиколлинеарности в данных - корреляция между TotalCharges и TotalDays - 0.82, что логично - чем дольше клиент платит, тем больше итоговая сумма. Удалили поле TotalCharges.
#
# 6) Дата регистрации новых клиентов: В начале 2014 года был большой прирост клиентов. Это связано с началом старта бизнеса. С начала 2015 по конец 2018 года - величина клиентов умеренно растёт. С начала 2019 года наблюдается бурный рост количества новых клиентов.
#
# 7) Дата ухода клиентов: Самые большие скочки оттока клиентов приходятся на 2019 и 2020 года.
#
# 8) Средняя длительность пользования услугами ушедших клиентов в два раза меньше, чем у тех, которые остались.
#
# 8) Был создан признак - длительность использования услуг компании TotalTime.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Здорово, что написал подробный вывод по исследовательскому анализу 👍
#
# Сейчас нужно добавить диаграммы для ушедших и оставшихся клиентов и добавить также небольшой аналитический вывод
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Добавил в распределении трат ушедших и настоящих клиентов диаграмму с выводом о том, что ушедшие клиенты в основном пользовались более дорогими тарифами.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо!
#
# </div>

# %% [markdown]
# ## Подготовим данные для моделей

# %% [markdown]
# ### Признаки с датой удалим

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Правильно, что удаляешь признаки, связанные с датами, из обучения моделей, иначе будет утечка
#
# </div>

# %%
df = df.drop(['BeginDate', 'EndDate'], axis=1)

# %%
df.head()
# Out:
#    customerID            Type PaperlessBilling              PaymentMethod  \
# 0  7590-VHVEG  Month-to-month              Yes           Electronic check
# 1  5575-GNVDE        One year               No               Mailed check
# 2  3668-QPYBK  Month-to-month              Yes               Mailed check
# 3  7795-CFOCW        One year               No  Bank transfer (automatic)
# 4  9237-HQITU  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges InternetService OnlineSecurity OnlineBackup  \
# 0              29             DSL             No          Yes
# 1              56             DSL            Yes           No
# 2              53             DSL            Yes          Yes
# 3              42             DSL            Yes           No
# 4              70     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  gender  \
# 0               No          No          No              No  Female
# ...

# %% [markdown]
# ### Разделим датафрейм на обучающую и тестовую выборки

# %%
# Целевой показатель Target
target = df['Target'] 
features = df.drop(columns=['Target'])

# %%
target.shape, features.shape
# Out:
# ((7043,), (7043, 18))

# %%
# Удалим CustomerID
features = features.drop(['customerID'], axis=1)

# %%
# Разделим датафрейм на обучающую и тестовую выбороки
features_train, features_test, target_train, target_test = train_test_split(features,
                                                                            target,
                                                                            test_size=0.25,
                                                                            random_state=RANDOM_STATE)

# %% [markdown]
# ### После удаления CustomerID закодируем с помощью OHE.

# %%
features_train.shape, features_test.shape
# Out:
# ((5282, 17), (1761, 17))

# %%
features_train = pd.get_dummies(features_train, drop_first=True)
features_test = pd.get_dummies(features_test, drop_first=True)

# %%
features_train.columns == features_test.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %% [markdown]
# Кодировка прошла успешно.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Отлично!
#
# </div>

# %% [markdown]
# ### Проверим баланс классов

# %%
# Проведем масштабирование количественных признаков
scaler = StandardScaler()

scaler.fit(features_train[numeric_columns])

features_train = features_train.copy()
features_train[numeric_columns] = scaler.transform(features_train[numeric_columns])

features_test = features_test.copy()
features_test[numeric_columns] = scaler.transform(features_test[numeric_columns])

# %%
target_train.value_counts().plot(
    kind='barh',
    color='k',
    figsize=(10, 5), 
    legend=False, 
    title='Распределение значений Target', 
).set(xlabel='Кол-во значений', ylabel='Значения')
plt.show()

# %%
rations = target_train[target_train == 1].count() / target_train[target_train == 0].count()
rations
# Out:
# 0.3585390946502058

# %% [markdown]
# Как мы видим, у нас дисбаланс классов.

# %% [markdown]
# ### Применим SMOTE для выравнивания классов

# %%
# target_train.info()

# %%
# !pip install -U imbalanced-learn

# %%
# from collections import Counter
# from imblearn.over_sampling import SMOTE, ADASYN

# %%
# X_resampled, y_resampled = SMOTE().fit_resample(features_train, target_train)
# print("Original dataset:", sorted(Counter(target_train).items()))
# print("Sampled dataset:", sorted(Counter(y_resampled).items()))

# sns.scatterplot(x=X_resampled[:,0], y=X_resampled[:,1], color='r', label='sampled')
# sns.scatterplot(x=features_train[:,0], y=features_train[:,1], hue=y)

# %%
# X_resampled.shape, y_resampled.shape

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> В данном проекте мы договорились, что не будем использовать upsampling, т.к. это дает слишком оптимистичную оценку на кросс-валидации
#
# Лучше учитывать баланс классов внутри моделей
#
# Можно еще использовать метод SMOTE из библиотеки imblearn, но тогда нужно использовать Pipeline для обучения моделей
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Получилось применить метод SMOTE, но без SCATTERPLOT.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v2:</b> Здорово, что попробовал SMOTE, это хороший задел на будущее
#
# Но опять же, мы не можем балансировать выборку, чтобы на ней посмотреть результат, он будет заведомо лучше, даже на кросс-валидации
#
# SMOTE нужно применять только в Pipeline, тогда метрика качества на кросс-валидации будет правильная/
#
# Пример pipeline + SMOTE:
#
#     pipeline = make_pipeline(
#         SMOTE(random_state=random_state),
#         RandomForestClassifier(random_state=random_state),
#     )
#
# Можешь пока что сделать без Pipeline, но тогда в обучение моделей нужно подавать выборку train, которая не отбалансирована в исходном виде
#
# На самом деле в этом проекте балансировка практически не нужна, т.к. ROC-AUC не чувствительна к дисбалансу
#
# Разве что проверить другие метрики, но тогда можно учесть баланс классов внутри моделей
# </div>

# %%
# y_resampled.value_counts().plot(
#     kind='barh',
#     color='k',
#     figsize=(10, 5), 
#     legend=False, 
#     title='Распределение значений y_resampled', 
# ).set(xlabel='Кол-во значений', ylabel='Значения')
# plt.show()

# %% [markdown]
# Применили метод SMOTE для выравнивания классов.

# %% [markdown]
# В данной работе у нас небольшой дисбаланс. Поэтому будем использовать наши первоначальные выборки.

# %%
features_train.shape, target_train.shape
# Out:
# ((5282, 22), (5282,))

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Дорогой ревьюер. Прошу Вас проверить мой проект. Дообучать модели я к сожалению не успел, но сделаю это в следующей части. Прошу ознакомиться и дать свои рекоменлации. С уважением, Артур. </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Артур, хорошая подготовка данных, можно сказать, что это примерно 80% всего проекта. Обучение моделей — уже дело техники. Есть несколько замечаний и рекомендаций:
#
# - в частности нужно убрать upsampling
#
# - дополнить исследовательский анализ данных;
#
# - поправить ошибку в кодировании
#
# При обучении моделей нужно сделать хотя бы в одной модели перебор гиперпараметров, использовать GridSearchCV или RandomizedSearchCV
#
# Лучшую модель выбрать на кросс-валидации, а затем ее проверить на тестировании
#
# Желательно также построить график ROC-кривой, посчитать метрику accuracy
#
# Еще можно исследовать значимость признаков для лучшей модели
#
# Если будут вопросы, пиши в Пачку. Буду ждать проект на очередную проверку!
#
# </div>

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Залача классификации. Для решения буду применять модели линейной регрессии, дерево решений, случайный лес и CatBoost.

# %%
def make_roc(target_test, predicted_test):
    fpr, tpr, thresholds = roc_curve(target_test, predicted_test)

    plt.figure()
    plt.plot(fpr, tpr,  color='r')
    plt.plot([0, 1], [0, 1], linestyle='-', color='k')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False')
    plt.ylabel('True')
    plt.title('ROC кривая')
    plt.show()

# %%
features_train.shape, features_test.shape, target_train.shape, target_test.shape
# Out:
# ((5282, 22), (1761, 22), (5282,), (1761,))

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v2:</b> Прежде, чем тестировать модель, необходимо сравнить все модели на кросс-валидации
#
# Затем только одну лучшую модель необходимо проверить на тестовой выборке
#
# Для сравнения качества моделей используй результат, полученный через best_score_
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v3:</b> На выборке test нужно проверить только одну лучшую модель
#
# Если проверяем все модели на выборке test, а затем их сравниваем, это неправильно, получается что мы подгоняемся под тестовую выборку
#
# У функции GridSearchCV есть метод, который позволяет оценить качество на кросс-валидации:
#
#     grid.best_score_
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v3: </b> Я исправил, обучил модели на тренировочной выборке. Попрошу вас ещё раз взглянуть на мой результат. С уважением, Артур. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v4:</b> Хорошо!
#
# </div>

# %% [markdown]
# ### Логистическая регрессия

# %%
param_grid = {'C': [10, 100, 1000, 10000]}
model = LogisticRegression(solver='lbfgs', penalty='l2')
grid = GridSearchCV(model, param_grid, cv=10, scoring='roc_auc')
grid.fit(features_train, target_train)
print('Лучшие параметры ', grid.best_params_)
print('BScore = ', grid.best_score_)
# Out:
# Лучшие параметры  {'C': 10}
# BScore =  0.8415592225989398

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v7:</b> Хорошо, все правильно!
#
# </div>

# %%
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v3: </b> Я исправил, обучил модели на тренировочной выборке. Попрошу вас ещё раз взглянуть на мой результат. С уважением, Артур. </div>

# %%
# make_roc(target_train, predict_true_probalities)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v4:</b> Хороший результат для логистической регрессии!
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v2:</b> Обычно параметр cv рекомендуют задавать не более 10, иначе получаются слишком маленькие разбиния, из-за этого качество на кросс-валидации неоправланно растет
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента V2: </b> Исправил. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v3:</b> Хорошо, так оценка будет точнее на кросс-валидации
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v4:</b> Расчет на тестовой выборке нужно убрать
#
# Если необходимо посчитать другие метрики, то можно использовать функцию cross_val_score
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
#
# В таком случае расчет нужно сделать на выборке train
#
# Выборку test мы не можем использовать на данном этапе
#
# </div>

# %% [markdown]
# Вполне неплохой результат, но до нужного ещё далеко.

# %% [markdown]
# ### Случайный лес

# %%
param_grid = {
    'max_depth': [50],
    'min_samples_split': range(2, 10, 2),
    'min_samples_leaf': range(2, 10, 2),
    'n_estimators': range(90, 101, 10)
}

model = RandomForestClassifier(random_state=RANDOM_STATE)

grid = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc')
grid.fit(features_train, target_train)
print('Лучшие параметры ', grid.best_params_)
print('BScore = ', grid.best_score_)
# Лучшие параметры  {'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100}
# Out:
# Лучшие параметры  {'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100}
# BScore =  0.8555329440937282

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %%
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v3:</b> Не нужно повторно обучать модель на тестовой выборке
#
# Если мы обучаем и проверяем модель на одной и той же выборке, как мы будем предсказывать неизвестные модели значения?
#
# </div>

# %% [markdown]
# ### Дерево решений

# %%
param_grid = {
    "criterion":["gini", "entropy"],
    "max_depth": (2, 41, 2),
    "min_samples_split": range(2, 21, 2),
    "min_samples_leaf": range(2, 11, 2)
}

model = DecisionTreeClassifier(random_state=RANDOM_STATE)

grid = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc')
grid.fit(features_train, target_train)
print('Лучшие параметры ', grid.best_params_)
print('BScore = ', grid.best_score_)

# Лучшие параметры  {'criterion': 'entropy', 'max_depth': 41, 'min_samples_leaf': 10, 'min_samples_split': 2}
# Out:
# Лучшие параметры  {'criterion': 'entropy', 'max_depth': 41, 'min_samples_leaf': 10, 'min_samples_split': 2}
# BScore =  0.8158965982584838

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %%
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %% [markdown]
# DecisionTreeClassifier очень сильно недотягивает до нужного результата.

# %% [markdown]
# ### Градиентный бустинг CatBoost

# %% [markdown]
# C помощью GridSearchCV подберём параметры для CatBoost

# %%
param_grid = {'learning_rate': np.logspace(-3, 0, 5),'iterations': range(20, 60, 20),
              'depth': range(6,11,2), 'l2_leaf_reg': range(3, 10, 2),
             }

model = CatBoostClassifier(loss_function='Logloss', eval_metric='AUC', devices='0:1', random_seed=RANDOM_STATE, thread_count=-1)
gs_result = model.grid_search(param_grid, features_train, target_train, verbose=0, train_size=0.8, plot=False, partition_random_seed=RANDOM_STATE)
gs_result['params']
print('BScore = ', grid.best_score_)

# {'depth': 6, 'l2_leaf_reg': 3, 'iterations': 40, 'learning_rate': 1.0}
#BScore =  0.8158965982584838
# Out:
# 0:	test: 0.8086974	best: 0.8086974 (0)	total: 50.3ms	remaining: 955ms
# 1:	test: 0.8157147	best: 0.8157147 (1)	total: 52.7ms	remaining: 474ms
# 2:	test: 0.8274514	best: 0.8274514 (2)	total: 55.2ms	remaining: 313ms
# 3:	test: 0.8316460	best: 0.8316460 (3)	total: 57ms	remaining: 228ms
# 4:	test: 0.8412697	best: 0.8412697 (4)	total: 59.7ms	remaining: 179ms
# 5:	test: 0.8408800	best: 0.8412697 (4)	total: 62.3ms	remaining: 145ms
# 6:	test: 0.8414522	best: 0.8414522 (6)	total: 65.2ms	remaining: 121ms
# 7:	test: 0.8408237	best: 0.8414522 (6)	total: 67.9ms	remaining: 102ms
# 8:	test: 0.8417203	best: 0.8417203 (8)	total: 69.8ms	remaining: 85.3ms
# 9:	test: 0.8414995	best: 0.8417203 (8)	total: 72.2ms	remaining: 72.2ms
# 10:	test: 0.8400690	best: 0.8417203 (8)	total: 74.1ms	remaining: 60.6ms
# 11:	test: 0.8412900	best: 0.8417203 (8)	total: 76ms	remaining: 50.6ms
# 12:	test: 0.8429165	best: 0.8429165 (12)	total: 77.8ms	remaining: 41.9ms
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %%
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Добавил best_score. </div>

# %%
# print('ROC-Auc', ra)
# print('F1 ', f1)
# make_roc(target_train, predict_true_probalities)

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v4:</b> Для удобства, можно также применить функцию GridSearchCV для модели Catboost
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v5:</b> Если модель обучается на выборке train без перебора параметров, то нужно использовать функцию cross_val_score для проверки качества. В параметре scoring тогда нужно выбрать roc_auc
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v4:</b> Сейчас во всех моделях используется выборка test для расчета метрик. Нужно убрать эту выборку, либо закомментировать код
#
# Можно также применить кросс-валидацию для расчета метрик на выборке train
#
# </div>

# %% [markdown]
# ### Анализ модели

# %% [markdown]
# Протестировали 4 модели. Самой лучшей оказалась CatBoost с результатом 0,81.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v7:</b> Поправь пожалуйста вывод, на кросс-валидации метрика явно не 0,97 должна получиться
#
# </div>

# %% [markdown]
# ### Тестирование итоговой модели

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v4:</b> Мы не можем обучать модель на выборке test
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v5:</b> Модель должна обучаться на выборке train, а не test:
#
#     model.fit(features_test, target_test)
#
# Так неправильно, тестовая выборка же нам недоступна, мы на ней только проверяем
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v6:</b> Зачем здесь эта строчка?
#
#     model.fit(features_test, target_test, plot = True, verbose = False)
#
# На тестовой выборке не нужна кросс-валидация
# </div>

# %%
model.fit(features_train, target_train)
predicted_test = model.predict(features_test)

probabilities_test = model.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]

accuracy = accuracy_score(target_test, predicted_test)
f1 = f1_score(target_test, predicted_test)

auc_roc = roc_auc_score(target_test, probabilities_one_test)
# Out:
# 0:	total: 2.62ms	remaining: 102ms
# 1:	total: 5.43ms	remaining: 103ms
# 2:	total: 8.38ms	remaining: 103ms
# 3:	total: 11.3ms	remaining: 102ms
# 4:	total: 14.2ms	remaining: 99.2ms
# 5:	total: 16.4ms	remaining: 92.8ms
# 6:	total: 18.6ms	remaining: 87.8ms
# 7:	total: 21.4ms	remaining: 85.5ms
# 8:	total: 23.5ms	remaining: 80.9ms
# 9:	total: 24.9ms	remaining: 74.7ms
# 10:	total: 26.9ms	remaining: 70.9ms
# 11:	total: 29.1ms	remaining: 67.9ms
# 12:	total: 32.1ms	remaining: 66.6ms
# 13:	total: 35.1ms	remaining: 65.2ms
# 14:	total: 38.2ms	remaining: 63.6ms
# 15:	total: 41.2ms	remaining: 61.8ms
# 16:	total: 44.6ms	remaining: 60.4ms
# 17:	total: 47.5ms	remaining: 58.1ms
# 18:	total: 49.9ms	remaining: 55.1ms
# 19:	total: 52ms	remaining: 52ms
# 20:	total: 54.2ms	remaining: 49ms
# 21:	total: 56.3ms	remaining: 46.1ms
# 22:	total: 58.5ms	remaining: 43.2ms
# 23:	total: 60.8ms	remaining: 40.5ms
# 24:	total: 62.9ms	remaining: 37.8ms
# 25:	total: 65.1ms	remaining: 35.1ms
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента v6: </b> Обучил модель на тренировочной выборке. Кросс-валидацию убрал на тесте. </div>

# %%
print('Accuracy:', accuracy)
print('F1 score:', f1)
print('AUC_ROC:', auc_roc)
# Out:
# Accuracy: 0.8637137989778535
# F1 score: 0.726027397260274
# AUC_ROC: 0.9131570762052876

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v7:</b> Отличный результат на тестовой выборке, поздравляю!
#
# </div>

# %%
make_roc(target_test, probabilities_one_test)

# %% [markdown]
# На тестовой выборке метрика намного лучше. Это говорит что наилучшую модель мы выбрали абсолютно правильно.
# Лучшими параметрами оказались {'depth': 6, 'l2_leaf_reg': 5, 'iterations': 1000, 'learning_rate': 0.3} для модели CatBoots.

# %% [markdown]
# ### График: значимость факторов

# %%
fig, ax = plt.subplots(figsize=(15,5))
fig.suptitle('График: значимость факторов')
sns.barplot(y=model.feature_importances_, x=features_test.columns, ax=ax)
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light')
plt.show()

# %% [markdown]
# Самыми важными признаками для качества модели оказались MonthlyCharges и время пользования услугами оператора. Признаки, которые меньше всего влияют на уход клиента - есть ли у человека партнер, дети, подключено ли у него стриминговое ТВ.

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента V5: </b> Постарался разобраться. Поправил метрики, обучение произвёл на тренировочной выборке. Подобрал лучшие параметры. Выбрал лучшую модель. Обучил на тесте. Построил ROC-кривую. Также написал заключение. </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента V6: </b> Я разобрался и поправил ваши замечания, сейчас мне самому смешно что я тупил на ровном месте. Извините пожалуйста за ваши потраченные нервы на меня. Прошу вас ещё разочек проверить мой код. С уважением, Артур. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v7:</b> Артур, здорово, что ты разобрался! Теперь все действия последовательные, метрика посчитана правильно.
#
# Ничего страшного, за меня не беспокойся, я смотрю на ошибки с профессиональной точки зрения, думаю как направить студентов в нужном направлении =)
#
# Я думаю это приятное чувство, когда сначала что-то было непонятно, а потом все получилось, поздравляю!
#
# Поправь еще вывод после кросс-валидации
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v5:</b> Здесь должен быть вывод, какая модель оказалась лучшей на кросс-валидации, какие параметры и метрика
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v4:</b> Необходимо добавить вывод, какие результаты получились на тестировании, гиперпараметры лучшей модели
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v2:</b> Нужно поправить расчет на ROC-AUC:
#
# - для расчета метрики roc_auc мы должны брать вероятность принадлежности к целевому классу
#
#
#     preds = best_model.predict_proba(X_test)[:, 1]
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента V2: </b> Исправил. </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v2:</b> Здорово, что добавил график ROC-кривой, но достаточно построить только для одной лучшей модели на тестовой выборке
#
# Еще в проекте хотелось бы увидеть одну из моделей бустинга
#
# Как рекомендация, можно добавить исследование значимости признаков для лучшей модели
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v2:</b> Как рекомендация, можно добавить исследование значимости признаков для лучшей модели
#
# Так мы сможем увидеть, какие признаки слабо влияют на отток, и в принципе их можно вообще исключить из обучения, и сделать новую модель, отобрав только самые важные признаки. (Пересчитывать с новыми признаками не нужно).
#
# Анализ важности признаков позволяет не только построить лучшую модель и уменьшить число признаков для обучения. Мы также можем выдать рекомендации бизнесу, изучив влияние признаков на отток, тем самым можно повысить качество определенных услуг, например онлайн-платежи или интернет на оптоволокне.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Вот небольшие статьи по метрикам в машинном обучении, если заинтересует:
#
# https://habr.com/ru/company/ods/blog/328372/
#
# https://habr.com/ru/company/jetinfosystems/blog/420261/
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v3:</b> Необходимо поправить замечания по кросс-валидации и тестированию моделей
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v4:</b> Остались замечания по обучению моделей
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v5:</b> Нужно оценить качество модели catboost на кросс-валидации, поправить тестирование
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Мы провели предобработку данных, исследовали и выявили следующее:
#
#     1. Столбец EndDate и BeginDate привели к типу datetime;
#     2. Столбец TotalCharge - float;
#     3. В столбце EndDate значения No заменили на дату актуальности датасета;
#     4. После объединения таблиц у нас получился новый датасет;
#     5. В столбце MultipleLines две категории и 682 пропущенных значения. Пропуски заполнили no_telefon - отсутствие телефона;
#     6. В общих расходах пользователя - TotalCharges было 11 пропусков. У этих пользователей начальная дата 01.02.2022.Заменили пропуски на значения столбца MonthlyCharges;
#     7. После предобработки избавились от всех пропусков. В датасете отсутствуют клиенты, которые вообще ничем не пользуются.
#
# Подготовили признаки:
#
#     1. Выделили целевой признак Target - показывает отказался клиень от услуг или нет;
#     2. Добавили столбец TotalTime, который показывает количество дней от заключения контракта до выгрузки данных 'TotalTime'.
#
# Сделали исследовательский анализ данных с визуализацией:
#
#     1. Распределение ежемесячных трат: Пик распределения величины ежемесячного платежа для ушедших клиетов выше, чем для оставшихся. Ушедшие клиенты платили больше.
#     2. Есть выбросы в общих платежах для ушедших клиентов. Они попадают в номарльные значения для оставшихся клиентов.
#     3. Можно заметить, что у нас присутствует проблема мультиколлинеарности в данных - корреляция между TotalCharges и TotalDays - 0.82, что логично - чем дольше клиент платит, тем больше итоговая сумма. Удалили поле TotalCharges.
#     4. Дата регистрации новых клиентов: В начале 2014 года был большой прирост клиентов. Это связано с началом старта бизнеса. С начала 2015 по конец 2018 года - величина клиентов умеренно растёт. С начала 2019 года наблюдается бурный рост количества новых клиентов.
#     7. Дата ухода клиентов: Самые большие скочки оттока клиентов приходятся на 2019 и 2020 года.
#     8. Средняя длительность пользования услугами ушедших клиентов в два раза меньше, чем у тех, которые остались.
#
# Подготовили данные для моделей.
#
# Обучили на тренировойчной выборке. Для предсказания оттока клиентов были обучены такие модели, как линейная регрессия, случайный лес, дерево решений, а также градиентный бустинг. Самой сильной из них оказался CatBoost, который применили мы на тестовой выборке и полчили AUC-Roc 0.976.
#
# Про значимость признаков можно сказать следующее: амыми важными признаками для качества модели оказались тип контракта и время пользования услугами оператора. Признаки, которые меньше всего влияют на уход клиента - есть ли у человека партнер, дети, подключено ли у него стриминговое ТВ.

# %% [markdown]
# ## ЗАКЛЮЧЕНИЕ

# %% [markdown]
# Работа над данным проектом была выполнена самостоятельно и показалась очень увлекательной. Можно сказать что на большинство вопросов по данной работе мы ответили в главном выводе.
#
#     - Я максимально постарался структурировать план работы и следовать ему по пунктам;
#     - Выполнили всю необходимую предобработку данных и подготовили новый датасет для исследовательского анализа;
#     - Рассмотрели 4 разные модели обучения и выбрали среди них лучшую.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v3:</b> Нужно добавить небольшой вывод по работе
#
# </div>

# %% [markdown]
# <font color=blue>
# <b> ✔️ 👍Заключение ревьювера:</b> Артур, у тебя хорошая работа и в целом она практически готова!
#
# Данные из разных таблиц собраны в один датафрейм, удалены аномалии, заполнены пропуски, получены новые признаки, а ненужные признаки удалены. Рассмотрено несколько моделей и сделан перебор параметров. Могу отметить самостоятельность и аналитический подход в выполнении проекта!
#
# Положительные моменты:
#
# - сгенерированы новые признаки;
#
# - проведен анализ данных и корреляции признаков;
#
# - рассмотрены несколько моделей для обучения, выполнен перебор гиперпараметров.
#
# Сейчас есть несколько замечаний:
#
# - тестирование выполнить только для одной модели;
#
# - если обучение без pipeline, то нужно убрать сэмплинг выборки перед обучением;
#
# - поправить расчет метрики roc-auc.
#
# На данном этапе проект практически завершен, я также отметил рекомендации. Я отправлю проект, чтобы ты мог ознакомиться с проверкой, внести изменения и возможно задать вопросы =)
#
# Также на будущее стоит иметь ввиду, что метрика ROC-AUC является не единственной, всегда нужно прислушиваться к требованиями бизнеса. Обычно одной метрикой не ограничиваются, смотрят также Precision, Recall, и выбирают те, которые наиболее подходят для конкретных задач.
#
# Еще нужно смотреть на важность признаков в модели, чтобы понимать, какие параметры влияют на отток.
#
# Проверка важности признаков по модели это только один из способов (корреляция в том числе). Используют также аналитические методы проверки гипотез.
#
# Если есть какие-то вопросы, или нужны пояснения по проекту — смело пиши! Я постараюсь тебе помочь 😊
#
# Жду твоего ответа!
#
# </font>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v7:</b> Артур, поздравляю с выполнением основной части проекта!
#
# Пожалуйста, сохрани наши с тобой комментарии, а отчет продолжай выполнять ниже, в этом файле Jupyter Notebook.
#
# В отчете не забудь указать все пункты по предобработке данных, параметрам модели, набору признаков для обучения — чтобы была возможность воспроизвести твою работу, изучив только отчет.
#
# Необходимо выделить следующие пункты:
#
# - список признаков, которые использовались для обучения;
#
# - указать итоговую модель и ее гиперпараметры — желательно в отдельной строке, чтобы не сливалась с остальным текстом;
#
# - отличия от исходного плана работ;
#
# - в отчете нужно указать трудности в работе (если не было, то так и написать) и ключевые этапы (если ключевых этапов не было, то написать, что все этапы важны);
#
# - размер тестовой выборки, параметр random_state.
#
# Я принимаю работу и буду ждать твой отчет на проверку!
#
# </div>

# %% [markdown]
# ## ОТЧЁТ

# %% [markdown]
# - Мы выделили целевой признак Target, который показывает отказался клиент от услуг или нет;
# - Итоговой моделью обучения у нас получилась CatBoost с параметрами
#         {'depth': 6, 'l2_leaf_reg': 3, 'iterations': 40, 'learning_rate': 1.0},
#
#         которые подобрали при помощи GridSearchCV;
# - План работы немного отличается от исходного, в процессе исследовательского анализа, мы пришли к выводу что применять методику дисбаланса мы не будем, потому что он у нас 35/65;
# - В данной работе особых трудностей не возникло. Самое главное правильно выделить целевой признак и проверить его значимость по отношению к остальным;
# - На протяжении всего обучения нас обучили правильно и последовательно подходить к каждому проекту. Поэтому без особых трудностостей мы выстроили план работы, расписали ключевые этапы, но а дальше, как говорится, дело техники;
# - После всех манипуляций, размер features_test у нас получился (1761, 17).
# - По поводу параметра random_state на вебинаре мы договаривались что он будет равен началу финишной прямой 270323.
